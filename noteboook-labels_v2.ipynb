# %%
import pystac
from pystac import Link, Asset
from datetime import datetime

# %%
from pystac.extensions.label import LabelExtension
from pystac.extensions.label import LabelType
from pystac.extensions.label import LabelClasses
from pystac.extensions.label import LabelStatistics

from pystac.extensions.version import ItemVersionExtension

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
aws_url = "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A"
# labels_geojson_fname = 'labels-v1.geojson'
labels_geojson_fname = 'label-train.geojson'

# %%
source_item = pystac.read_file(aws_url)
source_item
# Out:
# <Item id=S2A_10TFK_20220524_0_L2A>

# %%
source_item.get_assets()['SCL']
# Out:
# <Asset href=https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/T/FK/2022/5/S2A_10TFK_20220524_0_L2A/SCL.tif>

# %%
label_item = pystac.Item(
    id="label_{}".format("lu"),
    geometry=source_item.geometry,
    bbox=source_item.bbox,
    datetime=datetime.utcnow(),
    properties={},
)

# %%
label_classes = {
    "NO_DATA": 0,
    "SATURATED_OR_DEFECTIVE": 1,
    "CAST_SHADOWS": 2,
    "CLOUD_SHADOWS": 3,
    "VEGETATION": 4,
    "NOT_VEGETATED": 5,
    "WATER": 6,
    "UNCLASSIFIED": 7,
    "CLOUD_MEDIUM_PROBABILITY": 8,
    "CLOUD_HIGH_PROBABILITY": 9,
    "THIN_CIRRUS": 10,
    "SNOW or ICE": 11,
}

# %%
label = LabelExtension.ext(label_item, add_if_missing=True)
label.apply(
    label_description="Land cover labels",
    label_type=LabelType.VECTOR,
    label_tasks=["segmentation", "regression"],
    label_classes=[LabelClasses(label_classes)],
    label_methods=["manual"],
    label_properties=["class"],
)
label.add_source(source_item=source_item)
label.add_geojson_labels(labels_geojson_fname)

# %%
version = ItemVersionExtension(label_item)

version.apply(version="0.1", deprecated=False)

label_item.stac_extensions.append(
    "https://stac-extensions.github.io/version/v1.2.0/schema.json"
)

# %%
pystac.write_file(label_item, dest_href="label-item.json")

# %%
ml_aoi_item = pystac.Item(
    id="ml-aoi",
    geometry=source_item.geometry,
    bbox=source_item.bbox,
    datetime=datetime.utcnow(),
    properties={"ml-aoi:split": "train"},
)

# %%
ml_aoi_item.add_link(
    Link(
        rel="derived_from",
        target=aws_url,
        extra_fields={"ml-aoi:role": "feature"},
    )
)

ml_aoi_item.add_link(
    Link(
        rel="derived_from",
        target="label-item.json",
        extra_fields={"role": "ml-aoi:label"},
    )
)

# %%
label_asset = Asset(
    href=labels_geojson_fname,
    description="label",
    media_type=pystac.MediaType.GEOJSON,
    roles=["label"],
    extra_fields={"ml-aoi:role": "label"},
)

ml_aoi_item.add_asset(key="label", asset=label_asset)

# %%
ml_aoi_item.stac_extensions = [
    "https://stac-extensions.github.io/ml-aoi/v0.1.0/schema.json"
]

# %%
ml_item_fname = "ml-aoi-item.json"
pystac.write_file(ml_aoi_item, dest_href=ml_item_fname)

# %% [markdown]
# # Read ML STAC Item

# %%
import json

# %%
ml_item = pystac.read_file(ml_item_fname)
display(ml_item.properties)
# Out:
# {'ml-aoi:split': 'train', 'datetime': '2023-07-26T10:45:52.749205Z'}

# %%
label_href = ml_item.assets['label'].href
print('href of the geojson file:', label_href)
# Out:
# href of the geojson file: label-train.geojson

# %%
# Open asset (geojson format) and read all the coordinates within 
with open(label_href, 'r') as file:
    # Load the content of the file using the json module
    geojson_data = json.load(file)
geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'name': 'labels',
#  'features': [{'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.27859163156747, 40.38218701036475, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.19953674120562, 39.91585786896506, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.33843034984275, 40.4972903822101, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.68743345874819, 40.07457719936124, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.26139230895694, 40.290492371933254, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.74308928683688, 40.18555755803047, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6389470529706, 40.56726326945035, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.69538478759036, 40.44917135042127, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.5419727694332, 39.75660703796542, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.33944402091774, 39.878035273240194, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.14332070221522, 39.9699263180972, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.43443454462725, 40.301161869003444, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.4610553653892, 39.972148854823374, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.73647939488998, 40.18835530035312, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.75280540878154, 39.99589238356096, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.99717234182543, 39.974699577870254, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.08971243734953, 40.05328827081649, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.15474969268766, 40.0716397686962, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.79615841039588, 40.10053386002491, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.9638046482895, 40.54696521439289, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.00264103318396, 40.212533902614865, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.26708973201873, 40.20094100458392, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.85657871081267, 40.450710895973096, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.81158002765258, 40.550936933394155, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6790126588842, 40.171992887052696, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.57261191248429, 40.54634108178228, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02092705942806, 40.29878926633144, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.61257682726729, 40.218024311078324, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.61785508967337, 40.52917773643276, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.11007359192635, 40.47702521278236, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.61493474299843, 39.68224757635809, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.21252500191014, 40.15813016638638, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.51307584390669, 40.54543314660619, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.45596876982005, 40.548467480251745, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.46366813493619, 40.0749784853499, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.65100400496408, 40.037383655016534, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.55529943953142, 39.73668073380809, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.64217963889284, 40.011169962832156, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.48273503851229, 40.19324842389223, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.30997061048618, 39.79724608437679, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.49952493326917, 40.05490766696178, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.2453146881422, 40.143226729263574, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.45954509156195, 40.12780704250054, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.67694481883098, 40.57515014555667, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.42092216270927, 40.52718423329443, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.20296188552794, 40.08437976353359, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 2},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.0101588259625, 39.772850974993155, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 2},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.66534607234128, 39.70174077868453, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.60239787884443, 40.0298114405967, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6709897393419, 40.590163171223246, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.24247955137686, 40.32119621951164, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.49005629944295, 40.53981954815734, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.17037320886791, 40.24990094717412, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.94556753152816, 40.58726838106499, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.7660844518612, 40.441610166150646, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02523398056456, 40.23165949379946, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.48455366811018, 39.92083506814108, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1625256170828, 39.711217602803906, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.18564104397957, 39.76834029069762, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.49048220451887, 40.55766185628359, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.81974706265429, 39.794743947894695, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.48650882456772, 40.592472425860755, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.73720060579538, 39.868836801575796, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6228919375234, 40.48352196842928, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.83419501748394, 40.350843678796004, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.09407006323671, 40.14083543428441, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.70449328903112, 39.947736988029355, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.21383681725536, 40.545517528595035, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.74077754007655, 39.909445796045105, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.17548093006526, 39.68880832862683, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.99038702667352, 40.44771062514559, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.46934255214875, 40.464145712227875, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.76775577708062, 40.53352361704911, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.19605544870547, 40.49083111942887, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6191587404722, 40.31184414392363, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.5526960527144, 40.278658278433205, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.6224330847677, 40.545167486685195, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.07623418513606, 39.923787086300315, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.60877000997368, 40.19929880205721, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.62796050411112, 40.62144509138752, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.03676681347909, 40.37743238075347, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.45646083140124, 40.640089149685245, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.30739396574475, 39.78324393393204, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.89073174522672, 40.55376094370966, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80483299037331, 40.45494938292126, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.48958577508961, 40.31847138357464, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.96106613056149, 40.485391600996785, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.77139996478371, 40.233894599542765, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.20898120001254, 40.44400851946777, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.16980594132792, 40.113679819762154, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.74245762611305, 39.72614915473433, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.7693750098431, 40.24548034397307, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.58937327230652, 39.83360639287547, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.05908592939512, 40.161604739096894, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.71330973510186, 40.294016647304446, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.08704758628137, 40.05216322571779, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.71059181331162, 39.93465113159349, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.23516902776696, 40.058929293462704, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.07485552165866, 40.255828010090504, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02080707241942, 39.77609623457494, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.26581613974949, 40.38424821215545, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6146087526085, 40.5807249351369, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.7620127326705, 40.38306912897861, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.74179763677924, 39.69631667446826, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.71609515801562, 40.1905766819994, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.51475009491887, 39.860862690216926, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.5060357549117, 40.31436081177496, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.84963030321612, 39.70890529685363, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80007653730124, 40.26454165324511, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.03587492737061, 39.9521190623288, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.38171955984083, 40.576548137031416, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.47785259427306, 40.09102182665906, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02191833275867, 40.598600526202596, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.87748376804784, 39.99040621928127, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.33377691740098, 40.24597345459403, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80502256736777, 40.2574756767541, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.60019490585904, 40.348060616824235, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.40506212879646, 40.289319451677095, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.52587878598584, 40.13758956410651, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.59795741757411, 39.89108926155403, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.43612511182766, 40.12551109550746, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.75211655810092, 40.088216447913354, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02181546589712, 39.773500774298114, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.84569131622729, 39.857750590882446, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.59756569895485, 39.7627880931628, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1445060145626, 39.64795509355248, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.70407021867548, 40.1671778508717, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.80216705532851, 39.800358048209695, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.19251157034941, 40.168990282416786, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.7186630945783, 39.711810051859345, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.11417637622817, 40.46952528907963, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.25353395869273, 40.471985897925066, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.01971145905402, 40.12256087014602, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.66393618343359, 39.66094959934789, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.94600249918493, 39.888579805043236, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80525924576885, 40.002696126350116, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.24594408044112, 40.27827762144608, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.18133190659698, 39.69691853791818, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.2993890452328, 39.81429937123582, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.34196116723245, 39.836628312817005, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.81058094088618, 39.89583080809349, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.93939284174746, 40.05818859361987, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.58869608519073, 39.999619134722295, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.9239056286044, 40.55796528868389, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.14177067716996, 40.03143273320966, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.41844381769339, 40.30067406575478, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.19939808305439, 40.586370846060625, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.47722535478673, 40.19272561744063, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.82830877660169, 39.97013692346954, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.58680576140162, 40.08060053386112, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.75625850214357, 40.147752452700054, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.73353552650883, 40.2507693432944, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02469535238843, 39.68904325468681, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.61477310051947, 40.50623440242998, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.67862649866711, 39.95893603120838, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.82916359876798, 39.8480731068873, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.47654882534823, 40.4845101826083, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.64279189716639, 39.71088910236569, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.14732078443808, 39.782419877609385, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.04211748509441, 40.517871833471105, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.9615263738431, 39.96452857900554, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.75932491719318, 40.42852457492576, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 2},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6191663824539, 40.62540691565195, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.56662984541718, 40.60907922605327, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.7355832820497, 39.656976555737025, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.96237720762828, 40.010758783993765, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.50491525585981, 40.12470805439114, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.12955045173652, 40.31483049864315, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.44067057724898, 39.672851971382144, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.5490890862681, 39.76237230398296, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.53988808239271, 40.163082567554305, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.59825868469257, 40.396053975538976, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.28771213918847, 40.5751926139156, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.04442369890396, 39.65523192282572, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.86781305875358, 39.96995899135829, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.7867710248667, 40.090145269523326, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.2866241238452, 40.358073284657515, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.92358950050772, 40.57201207999031, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.94630168777779, 39.949034800987775, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.63765222231893, 40.13625595443069, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.69591828310227, 40.43377242750136, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.76946258937316, 39.94105707251348, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.8042931819787, 39.788596639161156, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.60074131745492, 40.075904753510464, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.3102435704532, 39.65706220277202, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6106621002961, 40.46246158881522, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.57773426214852, 40.28891411547058, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.64445629536, 40.165975872886484, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.60702835635472, 39.94561569084099, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.67010030708961, 40.50545764222542, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.71842366931234, 39.89122192090257, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1338643756212, 39.83959298304243, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.8747254088575, 40.331237205046605, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.01132836294146, 39.80926793705565, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.36746653162298, 39.95861575169853, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.00163396591525, 39.913966425775534, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.83716951685167, 40.555742835814385, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.41038480322588, 39.65640406310807, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.39886552966924, 39.972657722485714, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.3336685759896, 40.07273064074787, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.81045273171927, 39.95492576555736, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.58679840974362, 39.84039937535817, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.40889210777046, 40.47675191307811, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.96527590283848, 40.07089809047643, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.89687335726501, 40.19399411003093, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.21520329258806, 39.69951644153497, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.69948324974989, 39.70629633691226, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.87810342144672, 40.39994192108378, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.12868274583413, 40.33346406951533, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.15842204201451, 40.32205026150082, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.28235500235454, 39.65358975144281, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.71997981870291, 40.070652166049214, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.84626830613166, 40.182073003227764, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.75893773712255, 40.15383606850071, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.28594169455576, 39.94626735445608, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.22333891881223, 40.17568364507989, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.34635221553391, 40.487044331086175, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.60735637900562, 40.200040232275306, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.87540594847432, 40.320800112058826, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.7713890327543, 39.655829191131424, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.62425772210884, 40.55987313973307, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.17228232231892, 40.28380354662932, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.79631901310275, 40.07810232226549, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.4714207008567, 40.22102726091605, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.11286172882119, 40.503825320645994, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.00888492022423, 40.05922402653307, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.00693040172546, 40.48240849486878, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1716150505962, 40.13812230544924, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.93628199527636, 40.3970317304005, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.76191239349352, 40.06129064542548, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.10016994191922, 39.94679451952867, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.81748904543973, 39.89190712188242, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.62334330828331, 40.33302346395009, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.49905338222221, 40.00156698487214, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.50753778223206, 39.96699081563573, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.95648425093015, 39.74020583106011, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.81494416587829, 40.50920377404996, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.00871626074351, 40.4619005963349, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.68110475219454, 40.23820160431644, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.59950789802217, 40.06875773540908, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.74105932311839, 40.032418834721774, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 2},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.60794364699758, 40.62517488264149, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.04602484309586, 40.370923045562854, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.81588584678069, 39.67809551779838, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.55745364672288, 39.920683967528845, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.25374315592107, 40.57306248900036, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.73003862420752, 39.90828768487535, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.11340114479334, 40.450865445086244, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.55035077052338, 39.81702352216317, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.74404006124982, 39.727711449711926, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.66493089767302, 40.19909466342497, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.2599069427589, 40.03128557309593, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.50414418253885, 40.154518084537536, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.54939023716736, 40.55494831791456, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.51767006577583, 39.768552240773246, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.98206448085847, 40.129748303655255, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.74216090051749, 40.46392367644134, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.66136497797224, 40.128487870368005, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1728763599624, 40.270480190028664, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.54590421959726, 39.6639463965026, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.27952242003632, 39.795807495163615, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.95111169860608, 40.34702933229384, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.00075239434916, 40.31663927437011, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.49575825115997, 39.83115690815844, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.58026448571154, 40.537133692704934, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80742962503659, 40.414796911504084, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.98641842880954, 39.990008419063464, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.31617128399184, 39.71535010774469, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.34289572022676, 40.01133101004414, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.86076888781427, 40.329628589819514, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80911099293309, 40.446435192580424, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.12103920237234, 40.379823747157054, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.26090618648637, 40.27733240417097, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.00417953634718, 40.3920083335933, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.38391513445453, 40.095154476949574, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.16934221688201, 40.24889368671159, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80978366837543, 40.2273442670999, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.75123713195207, 40.540595875187016, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02446742049158, 40.217593064490295, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.53048102417651, 39.72609954027903, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.8439017206685, 39.95960690695623, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.93352615691303, 39.81331331423554, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1686194754328, 40.20591086621469, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.43038262016037, 40.063901429391606, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.68698844311795, 40.085762551841384, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.98954738496543, 40.49958313508876, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.73711469288098, 40.3932398001047, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.5308275335748, 40.00575810510734, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.5408130196713, 39.73965430760004, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.20568733941802, 40.04757548631678, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.82631067312506, 40.100803732472265, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.31659869145506, 40.412294731958305, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.20310435266654, 40.46986142933344, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.58517702925685, 40.15355475186816, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.68305824918501, 40.34353852946041, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.67466936657789, 40.339028348663675, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.6763593278322, 40.505259253556375, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.97935520424123, 40.15780794601084, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.62754753818693, 39.726657153958456, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.43265390134053, 40.56580995262703, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.08882373257899, 40.07669657296773, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.66426760738939, 39.97495290243912, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.67659160669432, 40.119680201960556, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.8815336483597, 39.95030127058413, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.22771121386495, 39.77583763972879, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.98165687580783, 39.849206071121195, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.86514761627619, 40.34754585330943, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.70975786620423, 40.48933041956174, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.17461230249499, 39.91600861656921, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.33045424070819, 39.94970993537474, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.9651946683519, 40.15233488211465, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.06793925175634, 39.77328703572565, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.08305870715041, 40.310916228858765, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.33548480339087, 40.1569906320208, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.15286288845542, 40.032961479010865, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.3299386905479, 39.66689733008218, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.68520356464738, 40.232932915840905, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.46734233639984, 40.05232412140018, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.94695368295625, 40.51486842364415, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.05949012118134, 39.79143469168455, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.34429279094697, 40.12306314861442, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.05709212126041, 40.37516334387261, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.09873201195163, 40.163073548174154, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.40983102427799, 39.95929484023367, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.61794747781471, 40.5365659947608, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.33548672765203, 40.31050062182496, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.89115807181946, 40.16992752237134, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.74048223886987, 39.93849344568376, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.5114618078069, 39.79117693173071, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.69792695110799, 39.6697148939613, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.79844740482694, 40.20371328643241, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.48634964269073, 39.940228635924065, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.7633839488682, 39.728446274021366, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.38691583876516, 39.783295648206945, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80620139731346, 39.71232412589401, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.61669179257133, 40.00632427328872, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.80106182694918, 40.18202830201627, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.65717209904611, 40.42386945695272, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.61737639199063, 40.549345194863186, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.12707681453483, 40.49766078998903, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.94130819723753, 39.77957764924435, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.74183740118633, 40.638957274118624, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.92935943985961, 40.006209461409405, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.69681514544425, 39.91227407500111, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.31038719288667, 40.51913440974887, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.43048693884462, 40.27345137353014, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.16049658048306, 40.0105605626978, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.7055405174025, 40.02252687801167, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.29962056537585, 40.379795646387564, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.36543592372946, 40.54659125587452, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.60234963265356, 39.70225810422924, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.98729685958493, 40.610253081721304, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.37062019268197, 40.03776060033045, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.6191419172872, 39.907830841014004, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.37661616350421, 39.96775349108713, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.92286289700449, 40.304546496367145, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.58037973552204, 40.39457459588632, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.2098294592565, 40.483118017293926, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.77521984085237, 40.23928302039181, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.658119711521, 40.427131519890324, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.39399283131674, 39.82042272492755, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.25523395323165, 40.00310706673799, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.57987164359764, 40.469297133567785, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02670826913005, 39.920792367569376, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.62292976162401, 40.096536207712994, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.95181620363958, 39.83075490747951, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.99831259645957, 39.71021349976085, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.8890653706215, 39.65115982964895, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.60349450135271, 40.07891102362319, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.65527918595221, 40.342579083350465, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.42814114603034, 39.98792373346361, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.23869071676981, 39.867179015887814, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.177963156973, 39.88669153535598, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.43243398901193, 39.67102922309809, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.74495128413123, 40.49143058514158, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.90252758508227, 40.166800986612714, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.9704422428752, 40.228369090731285, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1213156198549, 40.25100651307674, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.22951879587, 40.17739992511179, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.31861976886769, 40.487274693706524, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.33434387844942, 40.28516969893636, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.52697958389349, 40.37408736961334, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.40184807777312, 40.07071850370932, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.91408220432443, 39.66800875360392, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.99654228069484, 40.45088030164785, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.5478630632748, 39.89021037980907, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.12176174030641, 40.26038269670146, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.82143033337299, 39.81171234771652, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.88949184432988, 40.018822893852665, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.96012778569894, 40.55527781468857, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.89991248997617, 39.758565282619564, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 6},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.76406515806592, 40.60893793541142, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.44353066480599, 40.22263745584526, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.75469508857866, 39.72863145382958, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.6536224462708, 40.47847532458222, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.02037465129759, 40.02680914205466, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.89438025192172, 40.13025856746672, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.97854547202327, 40.038518835004666, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 4},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.41370578036583, 39.77609702052699, 0.0]}},
#   {'type': 'Feature',
#    'properties': {'class': 5},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.52303908719556, 40.596991950380676, 0.0]}}]}
